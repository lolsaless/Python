# %%
import pandas as pd

# %%
import os

# %%
basic_folder = 'new_data2'

file_list = os.listdir(f"./{basic_folder }")

# %%
file_list
# Out:
# ['product_england_automobile.xlsx',
#  'product_spain_semiconductor.xlsx',
#  'product_france_automobile.xlsx',
#  'product_england_battery.xlsx',
#  'product_italy_metaverse.xlsx',
#  'product_spain_automobile.xlsx',
#  'product_canada_automobile.xlsx',
#  'product_china_semiconductor.xlsx',
#  'product_italy_automobile.xlsx',
#  'product_italy_battery.xlsx',
#  'product_south_africa_semiconductor.xlsx',
#  'product_taiwan_battery.xlsx',
#  'product_america_metaverse.xlsx',
#  'product_america_battery.xlsx',
#  'product_france_battery.xlsx',
#  'product_spain_metaverse.xlsx',
#  'product_china_metaverse.xlsx',
#  'product_germany_metaverse.xlsx',
#  'product_canada_battery.xlsx',
#  'product_japan_automobile.xlsx',
#  'product_south_africa_metaverse.xlsx',
#  'product_japan_metaverse.xlsx',
#  'product_america_automobile.xlsx',
#  'product_germany_automobile.xlsx',
#  'product_china_battery.xlsx',
#  'product_canada_semiconductor.xlsx',
#  'product_canada_metaverse.xlsx',
# ...

# %%
file_list_xls = []
for i in file_list:
    if "xlsx" in i:
        file_list_xls.append(i)

file_list_xls
# Out:
# ['product_england_automobile.xlsx',
#  'product_spain_semiconductor.xlsx',
#  'product_france_automobile.xlsx',
#  'product_england_battery.xlsx',
#  'product_italy_metaverse.xlsx',
#  'product_spain_automobile.xlsx',
#  'product_canada_automobile.xlsx',
#  'product_china_semiconductor.xlsx',
#  'product_italy_automobile.xlsx',
#  'product_italy_battery.xlsx',
#  'product_south_africa_semiconductor.xlsx',
#  'product_taiwan_battery.xlsx',
#  'product_america_metaverse.xlsx',
#  'product_america_battery.xlsx',
#  'product_france_battery.xlsx',
#  'product_spain_metaverse.xlsx',
#  'product_china_metaverse.xlsx',
#  'product_germany_metaverse.xlsx',
#  'product_canada_battery.xlsx',
#  'product_japan_automobile.xlsx',
#  'product_south_africa_metaverse.xlsx',
#  'product_japan_metaverse.xlsx',
#  'product_america_automobile.xlsx',
#  'product_germany_automobile.xlsx',
#  'product_china_battery.xlsx',
#  'product_canada_semiconductor.xlsx',
#  'product_canada_metaverse.xlsx',
# ...

# %%
data_unit_sum = pd.DataFrame()

for i in file_list_xls:
    df = pd.read_excel(f"./{basic_folder }/" + i)
    df['나라'] = i.split("_")[1]
    data_unit = df[['나라', '조사제품', '제목', '내용']]
    data_unit_sum = pd.concat([data_unit_sum, data_unit], axis = 0)

data_unit_sum.to_excel('combiend_excel.xlsx')

# %%
df
# Out:
#    Unnamed: 0           조사제품  \
# 0           1  semiconductor
# 1           2  semiconductor
# 2           3  semiconductor
# 3           4  semiconductor
# 4           5  semiconductor
# 5           6  semiconductor
#
#                                                   제목  \
# 0                    미국 모기지금리 2배-일본 저금리 유지-한국 ‘금리역전’
# 1  Competition in Semiconductor Market Now Intern...
# 2                             Biden’s TikTok Problem
# 3  [ANALYSIS] Korea aspiring to become battery bu...
# 4         China Escalates Its Fight Against Big Tech
# 5  Lack of Tiny Parts Disrupts Auto Factories Wor...
#
#                                                   내용       나라
# 0  of England, the central bank of the UK, raised...  england
# 1  "The late founder remarked that England invent...  england
# 2  (WSJ) Semiconductor companies told Congress th...  england
# 3  to England in June. Also, it was reported that...  england
# 4  Further reading: A look at the $150 million se...  england
# ...

# %%
product_list = data_unit_sum['조사제품'].value_counts()
for i in dict(product_list):
    xls_name = data_unit_sum[data_unit_sum['조사제품'] == i]
    xls_name.to_excel(f"{i}.xlsx")

# %%
data_unit_sum['나라'].value_counts()
# Out:
# spain      35
# germany    35
# japan      33
# france     32
# canada     32
# china      31
# england    29
# taiwan     29
# america    29
# italy      26
# south      25
# Name: 나라, dtype: int64

# %%
i
# Out:
# 'semiconductor'

# %%
product_list
# Out:
# metaverse        89
# battery          86
# automobile       81
# semiconductor    80
# Name: 조사제품, dtype: int64

# %%
dict(product_list)
# Out:
# {'metaverse': 89, 'battery': 86, 'automobile': 81, 'semiconductor': 80}

# %%
xls_name
# Out:
#          나라           조사제품                                                 제목  \
# 0     spain  semiconductor  Yoon Suk-yeol, first lady, have an eventful fl...
# 1     spain  semiconductor  Yoon touts nuclear energy, green tech, chips a...
# 2     spain  semiconductor  S. Korea, US, Japan agree to step up pressure ...
# 3     spain  semiconductor  Yoon, Kishida exchange political pleasantries ...
# 4     spain  semiconductor                      (News Focus) Yoon-NATO summit
# ..      ...            ...                                                ...
# 1   england  semiconductor  Competition in Semiconductor Market Now Intern...
# 2   england  semiconductor                             Biden’s TikTok Problem
# 3   england  semiconductor  [ANALYSIS] Korea aspiring to become battery bu...
# 4   england  semiconductor         China Escalates Its Fight Against Big Tech
# 5   england  semiconductor  Lack of Tiny Parts Disrupts Auto Factories Wor...
#
# ...

# %% [markdown]
# # pandas 기본 문법

# %%
df = pd.read_excel("excel_sample.xlsx")

# %%
df
# Out:
#   Unnamed: 0        a         b          c
# 0          가        1        10        100
# 1          나     1000     10000     100000
# 2          다  1000000  10000000  100000000

# %%
df1 = df.transpose() # 행과 열을 바꿀 수 있다.

# %%
df1
# Out:
#               0       1          2
# Unnamed: 0    가       나          다
# a             1    1000    1000000
# b            10   10000   10000000
# c           100  100000  100000000

# %%
df1 = df1.rename(columns = df1.iloc[0])

# %%
df1
# Out:
#               가       나          다
# Unnamed: 0    가       나          다
# a             1    1000    1000000
# b            10   10000   10000000
# c           100  100000  100000000

# %%
df1 = df1.drop(df1.index[0])

# %%
df1
# Out:
#      가       나          다
# a    1    1000    1000000
# b   10   10000   10000000
# c  100  100000  100000000

# %%
df2 = df
df2.index = df2['Unnamed: 0'].values

# %%
df2
# Out:
#   Unnamed: 0        a         b          c
# 가          가        1        10        100
# 나          나     1000     10000     100000
# 다          다  1000000  10000000  100000000

# %%
df2.index
# Out:
# Index(['가', '나', '다'], dtype='object')

# %%
df.index
# Out:
# Index(['가', '나', '다'], dtype='object')

# %%
df2.drop(['Unnamed: 0'], axis = 1, inplace = True)

# %%
df2
# Out:
#          a         b          c
# 가        1        10        100
# 나     1000     10000     100000
# 다  1000000  10000000  100000000

# %%
file_list = os.listdir('row-columns_trans')
for file in file_list:
    df = pd.read_excel(f"row-columns_trans/{file}")
    df1 = df.transpose() # 행열 변환
    df1 = df1.rename(columns = df1.iloc[0])
    df1 = df1.drop(df1.index[0])
    display(df1)
    df1.to_excel(f"row-columns_trans/rctrans_{file}")
    df2 = df
    df2.index = df2["Unnamed: 0"].values
    df2.drop(["Unnamed: 0"], axis = 1, inplace = True)
    df2
    display(df2)
# Out:
#               0       1          2
# Unnamed: 0    가       나          다
# a             1    1000    1000000
# b            10   10000   10000000
# c           100  100000  100000000
#    Unnamed: 0.1        a         b          c
# 가             0        1        10        100
# 나             1     1000     10000     100000
# 다             2  1000000  10000000  100000000
#               0       1          2
# Unnamed: 0    가       나          다
# a             1    1000    1000000
# b            10   10000   10000000
# c           100  100000  100000000
#    Unnamed: 0.1        a         b          c
# 가             0        1        10        100
# 나             1     1000     10000     100000
# 다             2  1000000  10000000  100000000
#               0       1          2
# Unnamed: 0    가       나          다
# a             1    1000    1000000
# b            10   10000   10000000
# c           100  100000  100000000
#    Unnamed: 0.1        a         b          c
# ...

# %%
file_list = os.listdir('row-columns_trans')

# %%
file_list
# Out:
# ['excel_sample_3.xlsx',
#  'excel_sample_2.xlsx',
#  'excel_sample_9.xlsx',
#  'excel_sample_5.xlsx',
#  'excel_sample_4.xlsx',
#  'excel_sample_8.xlsx',
#  'excel_sample_7.xlsx',
#  'excel_sample_6.xlsx',
#  'excel_sample_1.xlsx',
#  'excel_sample_0.xlsx']

# %%
import pandas as pd
df1 = pd.DataFrame({'month': [1, 4, 7, 10],
                   'year': [2012, 2014, 2013, 2014],
                   'sale': [55, 40, 84, 31]})
df2 = pd.DataFrame({'month': [3, 5, 11, 10],
                   'year': [2015, 2016, 2017, 2018],
                   'sale': [12, 20, 34, 41]})

# %%
df1
# Out:
#    month  year  sale
# 0      1  2012    55
# 1      4  2014    40
# 2      7  2013    84
# 3     10  2014    31

# %%
df2
# Out:
#    month  year  sale
# 0      3  2015    12
# 1      5  2016    20
# 2     11  2017    34
# 3     10  2018    41

# %%
df1.transpose()
# Out:
#           0     1     2     3
# month     1     4     7    10
# year   2012  2014  2013  2014
# sale     55    40    84    31

# %%
pd.concat([df1, df2])
# Out:
#    month  year  sale
# 0      1  2012    55
# 1      4  2014    40
# 2      7  2013    84
# 3     10  2014    31
# 0      3  2015    12
# 1      5  2016    20
# 2     11  2017    34
# 3     10  2018    41

# %%
pd.concat([df1, df2]).transpose()
# Out:
#           0     1     2     3     0     1     2     3
# month     1     4     7    10     3     5    11    10
# year   2012  2014  2013  2014  2015  2016  2017  2018
# sale     55    40    84    31    12    20    34    41

# %% [markdown]
# ## pandas 기본문법

# %%
import pandas as pd
data = pd.read_csv("test_df.csv")

# %%
data = data.set_index("행번")

# %%
data
# Out:
#      이름         조사일   몸무게  단위    트레이너  지점명
# 행번
# 1   비현코  2019-01-01  70.0  kg   jason  잠실동
# 2   비현코  2019-03-01  68.0  kg   jason   잠실
# 3   비현코  2019-06-01   NaN  kg   jason  잠실동
# 4   비투코  2019-01-01  80.0  kg   jason   잠실
# 5   비투코  2019-03-01  75.0  kg   jason   잠실
# 6   비투코  2019-06-01   NaN  kg   jason   잠실
# 7   비사코  2019-01-01  89.0  kg  cherry   강남
# 8   비사코  2019-03-01   NaN  kg  cherry   강남
# 9   비사코  2019-06-01  92.0  kg  cherry   강남

# %%
data.index
# Out:
# Int64Index([1, 2, 3, 4, 5, 6, 7, 8, 9], dtype='int64', name='행번')

# %%
data.columns
# Out:
# Index(['이름', '조사일', '몸무게', '단위', '트레이너', '지점명'], dtype='object')

# %%
data.row
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/m4/nljjtp490j73jshmn9k7r0wh0000gn/T/ipykernel_3723/3603130030.py in ?()
# ----> 1 data.row
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5898             and name not in self._accessors
#    5899             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'row'

# %%
data.iloc[0] # 순번대로
# Out:
# 이름             비현코
# 조사일     2019-01-01
# 몸무게           70.0
# 단위              kg
# 트레이너         jason
# 지점명            잠실동
# Name: 1, dtype: object

# %%
data.loc[1] # 인덱스
# Out:
# 이름             비현코
# 조사일     2019-01-01
# 몸무게           70.0
# 단위              kg
# 트레이너         jason
# 지점명            잠실동
# Name: 1, dtype: object

# %%
data.shape
# Out:
# (9, 6)

# %%
data.head()
# Out:
#      이름         조사일   몸무게  단위   트레이너  지점명
# 행번
# 1   비현코  2019-01-01  70.0  kg  jason  잠실동
# 2   비현코  2019-03-01  68.0  kg  jason   잠실
# 3   비현코  2019-06-01   NaN  kg  jason  잠실동
# 4   비투코  2019-01-01  80.0  kg  jason   잠실
# 5   비투코  2019-03-01  75.0  kg  jason   잠실

# %%
data.head(3)
# Out:
#      이름         조사일   몸무게  단위   트레이너  지점명
# 행번
# 1   비현코  2019-01-01  70.0  kg  jason  잠실동
# 2   비현코  2019-03-01  68.0  kg  jason   잠실
# 3   비현코  2019-06-01   NaN  kg  jason  잠실동

# %%
data.tail(2)
# Out:
#      이름         조사일   몸무게  단위    트레이너 지점명
# 행번
# 8   비사코  2019-03-01   NaN  kg  cherry  강남
# 9   비사코  2019-06-01  92.0  kg  cherry  강남

# %%
data["몸무게"].min()
# Out:
# 68.0

# %%
data["몸무게"].max()
# Out:
# 92.0

# %%
data["몸무게"].sum()
# Out:
# 474.0

# %%
data['몸무게'].describe()
# Out:
# count     6.000000
# mean     79.000000
# std       9.879271
# min      68.000000
# 25%      71.250000
# 50%      77.500000
# 75%      86.750000
# max      92.000000
# Name: 몸무게, dtype: float64

# %%
data["지점명"] = data["지점명"].replace("잠실동", "잠실")

# %%
data
# Out:
#      이름         조사일   몸무게  단위    트레이너 지점명
# 행번
# 1   비현코  2019-01-01  70.0  kg   jason  잠실
# 2   비현코  2019-03-01  68.0  kg   jason  잠실
# 3   비현코  2019-06-01   NaN  kg   jason  잠실
# 4   비투코  2019-01-01  80.0  kg   jason  잠실
# 5   비투코  2019-03-01  75.0  kg   jason  잠실
# 6   비투코  2019-06-01   NaN  kg   jason  잠실
# 7   비사코  2019-01-01  89.0  kg  cherry  강남
# 8   비사코  2019-03-01   NaN  kg  cherry  강남
# 9   비사코  2019-06-01  92.0  kg  cherry  강남

# %%
data["몸무게"].isnull()
# Out:
# 행번
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: 몸무게, dtype: bool

# %%
data["몸무게"] = data["몸무게"].fillna(75.8)

# %%
data
# Out:
#      이름         조사일   몸무게  단위    트레이너 지점명
# 행번
# 1   비현코  2019-01-01  70.0  kg   jason  잠실
# 2   비현코  2019-03-01  68.0  kg   jason  잠실
# 3   비현코  2019-06-01  75.8  kg   jason  잠실
# 4   비투코  2019-01-01  80.0  kg   jason  잠실
# 5   비투코  2019-03-01  75.0  kg   jason  잠실
# 6   비투코  2019-06-01  75.8  kg   jason  잠실
# 7   비사코  2019-01-01  89.0  kg  cherry  강남
# 8   비사코  2019-03-01  75.8  kg  cherry  강남
# 9   비사코  2019-06-01  92.0  kg  cherry  강남

# %%
data["몸무게(prev+1)"] = data["몸무게"].shift(1)

# %%
data
# Out:
#      이름         조사일   몸무게  단위    트레이너 지점명
# 행번
# 1   비현코  2019-01-01  70.0  kg   jason  잠실
# 2   비현코  2019-03-01  68.0  kg   jason  잠실
# 3   비현코  2019-06-01  75.8  kg   jason  잠실
# 4   비투코  2019-01-01  80.0  kg   jason  잠실
# 5   비투코  2019-03-01  75.0  kg   jason  잠실
# 6   비투코  2019-06-01  75.8  kg   jason  잠실
# 7   비사코  2019-01-01  89.0  kg  cherry  강남
# 8   비사코  2019-03-01  75.8  kg  cherry  강남
# 9   비사코  2019-06-01  92.0  kg  cherry  강남

# %%
data["몸무게(next-1)"] = data["몸무게"].shift(-1)
data
# Out:
#      이름         조사일   몸무게  단위    트레이너 지점명  몸무게(next-1)
# 행번
# 1   비현코  2019-01-01  70.0  kg   jason  잠실         68.0
# 2   비현코  2019-03-01  68.0  kg   jason  잠실         75.8
# 3   비현코  2019-06-01  75.8  kg   jason  잠실         80.0
# 4   비투코  2019-01-01  80.0  kg   jason  잠실         75.0
# 5   비투코  2019-03-01  75.0  kg   jason  잠실         75.8
# 6   비투코  2019-06-01  75.8  kg   jason  잠실         89.0
# 7   비사코  2019-01-01  89.0  kg  cherry  강남         75.8
# 8   비사코  2019-03-01  75.8  kg  cherry  강남         92.0
# 9   비사코  2019-06-01  92.0  kg  cherry  강남          NaN

# %%
data[["이름", "조사일", "몸무게"]]
# Out:
#      이름         조사일   몸무게
# 행번
# 1   비현코  2019-01-01  70.0
# 2   비현코  2019-03-01  68.0
# 3   비현코  2019-06-01  75.8
# 4   비투코  2019-01-01  80.0
# 5   비투코  2019-03-01  75.0
# 6   비투코  2019-06-01  75.8
# 7   비사코  2019-01-01  89.0
# 8   비사코  2019-03-01  75.8
# 9   비사코  2019-06-01  92.0

# %% [markdown]
# data[["이름", "조사일", "몸무게"]]: 이 구문은 여러 열을 선택하는 것으로, 결과는 DataFrame이 됩니다. 여러 열을 선택하려면 열 이름을 리스트로 감싸주어야 합니다.
#
# data["이름", "조사일", "몸무게"]: 이 구문은 하나의 열을 선택하려고 시도하는데, 여러 열 이름을 콤마로 나열했기 때문에 에러가 발생합니다. Pandas에서는 하나의 열을 선택할 때는 열 이름을 리스트로 감싸주지 않아도 되지만, 여러 열을 선택할 때는 리스트로 감싸주어야 합니다.

# %%
data.loc[[1, 2, 3, 4]]
# Out:
#      이름         조사일   몸무게  단위   트레이너 지점명  몸무게(next-1)
# 행번
# 1   비현코  2019-01-01  70.0  kg  jason  잠실         68.0
# 2   비현코  2019-03-01  68.0  kg  jason  잠실         75.8
# 3   비현코  2019-06-01  75.8  kg  jason  잠실         80.0
# 4   비투코  2019-01-01  80.0  kg  jason  잠실         75.0

# %%
data[0:4]
# Out:
#      이름         조사일   몸무게  단위   트레이너 지점명  몸무게(next-1)
# 행번
# 1   비현코  2019-01-01  70.0  kg  jason  잠실         68.0
# 2   비현코  2019-03-01  68.0  kg  jason  잠실         75.8
# 3   비현코  2019-06-01  75.8  kg  jason  잠실         80.0
# 4   비투코  2019-01-01  80.0  kg  jason  잠실         75.0

# %%
data.iloc[0:4]
# Out:
#      이름         조사일   몸무게  단위   트레이너 지점명  몸무게(next-1)
# 행번
# 1   비현코  2019-01-01  70.0  kg  jason  잠실         68.0
# 2   비현코  2019-03-01  68.0  kg  jason  잠실         75.8
# 3   비현코  2019-06-01  75.8  kg  jason  잠실         80.0
# 4   비투코  2019-01-01  80.0  kg  jason  잠실         75.0

# %%
data.iloc[0:3], [["이름", "조사일", "몸무게"]]
# Out:
# (     이름         조사일   몸무게  단위   트레이너 지점명  몸무게(next-1)
#  행번
#  1   비현코  2019-01-01  70.0  kg  jason  잠실         68.0
#  2   비현코  2019-03-01  68.0  kg  jason  잠실         75.8
#  3   비현코  2019-06-01  75.8  kg  jason  잠실         80.0,
#  [['이름', '조사일', '몸무게']])

# %%
data.loc[[1, 2, 3], ["이름", "조사일", "몸무게"]]
# Out:
#      이름         조사일   몸무게
# 행번
# 1   비현코  2019-01-01  70.0
# 2   비현코  2019-03-01  68.0
# 3   비현코  2019-06-01  75.8

# %%
data["트레이너"] == "jason"
# Out:
# 행번
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7    False
# 8    False
# 9    False
# Name: 트레이너, dtype: bool

# %%
data[data["트레이너"] == "jason"]
# Out:
#      이름         조사일   몸무게  단위   트레이너 지점명  몸무게(next-1)
# 행번
# 1   비현코  2019-01-01  70.0  kg  jason  잠실         68.0
# 2   비현코  2019-03-01  68.0  kg  jason  잠실         75.8
# 3   비현코  2019-06-01  75.8  kg  jason  잠실         80.0
# 4   비투코  2019-01-01  80.0  kg  jason  잠실         75.0
# 5   비투코  2019-03-01  75.0  kg  jason  잠실         75.8
# 6   비투코  2019-06-01  75.8  kg  jason  잠실         89.0

# %%
data[data["트레이너"].str.contains("j")]
# Out:
#      이름         조사일   몸무게  단위   트레이너 지점명  몸무게(next-1)
# 행번
# 1   비현코  2019-01-01  70.0  kg  jason  잠실         68.0
# 2   비현코  2019-03-01  68.0  kg  jason  잠실         75.8
# 3   비현코  2019-06-01  75.8  kg  jason  잠실         80.0
# 4   비투코  2019-01-01  80.0  kg  jason  잠실         75.0
# 5   비투코  2019-03-01  75.0  kg  jason  잠실         75.8
# 6   비투코  2019-06-01  75.8  kg  jason  잠실         89.0

# %%
high = (data["몸무게"] > 75.5)
kim = (data["트레이너"] == "cherry")

# %%
data[high&kim]
# Out:
#      이름         조사일   몸무게  단위    트레이너 지점명  몸무게(next-1)
# 행번
# 7   비사코  2019-01-01  89.0  kg  cherry  강남         75.8
# 8   비사코  2019-03-01  75.8  kg  cherry  강남         92.0
# 9   비사코  2019-06-01  92.0  kg  cherry  강남          NaN

# %%
data[high|kim]
# Out:
#      이름         조사일   몸무게  단위    트레이너 지점명  몸무게(next-1)
# 행번
# 3   비현코  2019-06-01  75.8  kg   jason  잠실         80.0
# 4   비투코  2019-01-01  80.0  kg   jason  잠실         75.0
# 6   비투코  2019-06-01  75.8  kg   jason  잠실         89.0
# 7   비사코  2019-01-01  89.0  kg  cherry  강남         75.8
# 8   비사코  2019-03-01  75.8  kg  cherry  강남         92.0
# 9   비사코  2019-06-01  92.0  kg  cherry  강남          NaN

# %%
pd.pivot_table(data, index = "트레이너", values = "몸무게")
# Out:
#          몸무게
# 트레이너
# cherry  85.6
# jason   74.1

# %%
pd.pivot_table(data, index = ["트레이너", "지점명"], values = "몸무게")
# Out:
#              몸무게
# 트레이너   지점명
# cherry 강남   85.6
# jason  잠실   74.1

# %%
pd.pivot_table(data, index = ["트레이너", "지점명"], values = "몸무게", aggfunc = ["sum", "mean"])
# Out:
#               sum  mean
#               몸무게   몸무게
# 트레이너   지점명
# cherry 강남   256.8  85.6
# jason  잠실   444.6  74.1

# %%
data246 = data.loc[[2, 4, 6]]

# %%
data246
# Out:
#      이름         조사일   몸무게  단위   트레이너 지점명  몸무게(next-1)
# 행번
# 2   비현코  2019-03-01  68.0  kg  jason  잠실         75.8
# 4   비투코  2019-01-01  80.0  kg  jason  잠실         75.0
# 6   비투코  2019-06-01  75.8  kg  jason  잠실         89.0

# %%
data389 = data.loc[[3, 8, 9]]

# %%
pd.concat([data246, data389], axis = 0)
# Out:
#      이름         조사일   몸무게  단위    트레이너 지점명  몸무게(next-1)
# 행번
# 2   비현코  2019-03-01  68.0  kg   jason  잠실         75.8
# 4   비투코  2019-01-01  80.0  kg   jason  잠실         75.0
# 6   비투코  2019-06-01  75.8  kg   jason  잠실         89.0
# 3   비현코  2019-06-01  75.8  kg   jason  잠실         80.0
# 8   비사코  2019-03-01  75.8  kg  cherry  강남         92.0
# 9   비사코  2019-06-01  92.0  kg  cherry  강남          NaN

# %%
data
# Out:
#      이름         조사일   몸무게  단위    트레이너 지점명  몸무게(next-1)
# 행번
# 1   비현코  2019-01-01  70.0  kg   jason  잠실         68.0
# 2   비현코  2019-03-01  68.0  kg   jason  잠실         75.8
# 3   비현코  2019-06-01  75.8  kg   jason  잠실         80.0
# 4   비투코  2019-01-01  80.0  kg   jason  잠실         75.0
# 5   비투코  2019-03-01  75.0  kg   jason  잠실         75.8
# 6   비투코  2019-06-01  75.8  kg   jason  잠실         89.0
# 7   비사코  2019-01-01  89.0  kg  cherry  강남         75.8
# 8   비사코  2019-03-01  75.8  kg  cherry  강남         92.0
# 9   비사코  2019-06-01  92.0  kg  cherry  강남          NaN
