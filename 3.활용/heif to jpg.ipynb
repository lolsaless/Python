# %%
import os
import pyheif
from PIL import Image

# 변환할 폴더 경로 설정
input_folder = "/Users/lol/Documents/GitHub/Photos-001"
output_folder = os.path.join(input_folder, "converted_jpg")

# 출력 폴더가 없으면 생성
os.makedirs(output_folder, exist_ok=True)

# 폴더 내 모든 HEIC/HEIF 파일 변환
for filename in os.listdir(input_folder):
    if filename.lower().endswith((".heic", ".heif")):
        input_path = os.path.join(input_folder, filename)
        output_path = os.path.join(output_folder, f"{os.path.splitext(filename)[0]}.jpg")

        try:
            # HEIC 파일 열기 및 변환
            heif_file = pyheif.read(input_path)
            image = Image.frombytes(heif_file.mode, heif_file.size, heif_file.data, "raw", heif_file.mode)

            # JPG로 저장
            image.convert("RGB").save(output_path, "JPEG", quality=95)
            print(f"✅ 변환 완료: {filename} → {output_path}")

        except Exception as e:
            print(f"⚠️ 변환 실패: {filename} | 오류: {e}")

print("✅ 모든 변환이 완료되었습니다!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import os
# ----> 2 import pyheif
#       3 from PIL import Image
#       5 # 변환할 폴더 경로 설정
#
# ModuleNotFoundError: No module named 'pyheif'

# %%
import os
import subprocess

input_folder = "/Users/lol/Documents/GitHub/Photos-001"
output_folder = os.path.join(input_folder, "converted_jpg")

os.makedirs(output_folder, exist_ok=True)

for filename in os.listdir(input_folder):
    if filename.lower().endswith(".heic"):
        input_path = os.path.join(input_folder, filename)
        output_path = os.path.join(output_folder, f"{os.path.splitext(filename)[0]}.jpg")

        try:
            subprocess.run(["ffmpeg", "-i", input_path, output_path], check=True)
            print(f"✅ 변환 완료: {filename} → {output_path}")
        except Exception as e:
            print(f"⚠️ 변환 실패: {filename} | 오류: {e}")

print("✅ 모든 변환이 완료되었습니다!")
# Out:
# ⚠️ 변환 실패: IMG_5422.HEIC | 오류: [Errno 2] No such file or directory: 'ffmpeg'
# ⚠️ 변환 실패: IMG_5418.HEIC | 오류: [Errno 2] No such file or directory: 'ffmpeg'
# ⚠️ 변환 실패: IMG_5419.HEIC | 오류: [Errno 2] No such file or directory: 'ffmpeg'
# ⚠️ 변환 실패: IMG_5423.HEIC | 오류: [Errno 2] No such file or directory: 'ffmpeg'
# ⚠️ 변환 실패: IMG_5428.HEIC | 오류: [Errno 2] No such file or directory: 'ffmpeg'
# ⚠️ 변환 실패: IMG_5429.HEIC | 오류: [Errno 2] No such file or directory: 'ffmpeg'
# ⚠️ 변환 실패: IMG_5425.HEIC | 오류: [Errno 2] No such file or directory: 'ffmpeg'
# ⚠️ 변환 실패: IMG_5430.HEIC | 오류: [Errno 2] No such file or directory: 'ffmpeg'
# ⚠️ 변환 실패: IMG_5426.HEIC | 오류: [Errno 2] No such file or directory: 'ffmpeg'
# ⚠️ 변환 실패: IMG_5427.HEIC | 오류: [Errno 2] No such file or directory: 'ffmpeg'
# ⚠️ 변환 실패: IMG_5431.HEIC | 오류: [Errno 2] No such file or directory: 'ffmpeg'
# ✅ 모든 변환이 완료되었습니다!

# %%
import os
import subprocess

input_folder = "/Users/lol/Documents/GitHub/Photos-001"
output_folder = os.path.join(input_folder, "converted_jpg")

os.makedirs(output_folder, exist_ok=True)

# 환경 변수에 FFmpeg 경로 추가
os.environ["PATH"] += os.pathsep + "/opt/homebrew/bin" # macOS Homebrew 기준

for filename in os.listdir(input_folder):
    if filename.lower().endswith(".heic"):
        input_path = os.path.join(input_folder, filename)
        output_path = os.path.join(output_folder, f"{os.path.splitext(filename)[0]}.jpg")

        try:
            subprocess.run(["ffmpeg", "-i", input_path, output_path], check=True)
            print(f"✅ 변환 완료: {filename} → {output_path}")
        except Exception as e:
            print(f"⚠️ 변환 실패: {filename} | 오류: {e}")

print("✅ 모든 변환이 완료되었습니다!")
# Out:
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_5802.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5802.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 4032x3024 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x14bf13100] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5802.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x14bf13100] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x14bf10630] video:613KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=13.6 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.511x
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_5793.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5793.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 4032x3024 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# ✅ 변환 완료: IMG_5802.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5802.jpg
# ✅ 변환 완료: IMG_5793.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5793.jpg
# [image2 @ 0x12f0047d0] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5793.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x12f0047d0] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x12f004710] video:603KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=12.8 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.472x
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_5803.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5803.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 4032x3024 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x130007460] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5803.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x130007460] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x1300073a0] video:562KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=13.1 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.649x
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_5824.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# ✅ 변환 완료: IMG_5803.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5803.jpg
# ✅ 변환 완료: IMG_5824.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5824.jpg
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5824.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 3024x4032 [SAR 1:1 DAR 3:4], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x11c706af0] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5824.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x11c706af0] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x11c706a30] video:912KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=15.4 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.403x
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_5808.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5808.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 3024x4032 [SAR 1:1 DAR 3:4], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x138704fe0] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5808.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x138704fe0] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x138704f20] video:414KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=13.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.576x
# ✅ 변환 완료: IMG_5808.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5808.jpg
# ✅ 변환 완료: IMG_5799.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5799.jpg
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_5799.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5799.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 3024x4032 [SAR 1:1 DAR 3:4], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x136f071c0] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5799.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x136f071c0] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x116e04080] video:480KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=13.9 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.643x
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_5804.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5804.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 4032x3024 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x130631860] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5804.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x130631860] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x1306317a0] video:562KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=13.3 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.654x
# ✅ 변환 완료: IMG_5804.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5804.jpg
# ✅ 변환 완료: IMG_5812.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5812.jpg
# ✅ 변환 완료: IMG_5805.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5805.jpg
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_5812.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5812.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 4032x3024 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x13ab08340] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5812.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x13ab08340] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x13ab08140] video:366KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=13.4 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.796x
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_5805.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5805.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 4032x3024 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x141906970] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5805.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x141906970] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x1419068b0] video:469KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=12.5 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.742x
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_5798.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5798.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 4032x3024 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x136705090] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5798.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x136705090] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x136704fd0] video:596KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=13.8 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.58x
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_5809.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5809.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 4032x3024 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x122708230] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5809.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x122708230] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x122708170] video:489KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=12.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.639x
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_5825.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# ✅ 변환 완료: IMG_5798.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5798.jpg
# ✅ 변환 완료: IMG_5809.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5809.jpg
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5825.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 4032x3024 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x144707480] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5825.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x144707480] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x1447073c0] video:696KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=14.1 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.518x
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_5810.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5810.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 4032x3024 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x13ce314a0] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5810.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x13ce314a0] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x13ce313e0] video:674KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=14.4 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.566x
# ✅ 변환 완료: IMG_5825.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5825.jpg
# ✅ 변환 완료: IMG_5810.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5810.jpg
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_5797.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5797.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 4032x3024 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x146706dd0] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5797.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x146706dd0] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x146707d60] video:533KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=12.8 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.653x
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_5806.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5806.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 4032x3024 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x11f631760] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5806.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x11f631760] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x11f6311f0] video:510KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=12.8 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.681x
# ✅ 변환 완료: IMG_5797.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5797.jpg
# ✅ 변환 완료: IMG_5806.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5806.jpg
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_5807.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5807.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 3024x4032 [SAR 1:1 DAR 3:4], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x1440074e0] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5807.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x1440074e0] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x144007420] video:440KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=13.5 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.681x
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_5796.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5796.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 4032x3024 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x154705a30] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5796.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x154705a30] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x154705970] video:504KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=13.1 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.729x
# ✅ 변환 완료: IMG_5807.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5807.jpg
# ✅ 변환 완료: IMG_5796.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5796.jpg
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_5811.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5811.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 3024x4032 [SAR 1:1 DAR 3:4], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x1266047c0] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5811.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x1266047c0] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x1266056f0] video:392KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=11.8 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.642x
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_5800.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5800.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 4032x3024 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x1577337e0] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5800.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x1577337e0] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x157733720] video:559KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=13.8 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.67x
# ✅ 변환 완료: IMG_5811.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5811.jpg
# ✅ 변환 완료: IMG_5800.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5800.jpg
# ✅ 변환 완료: IMG_5801.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5801.jpg
# ✅ 모든 변환이 완료되었습니다!
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_5801.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5801.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 4032x3024 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x149805090] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_5801.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x149805090] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x149804fd0] video:485KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=12.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.722x
