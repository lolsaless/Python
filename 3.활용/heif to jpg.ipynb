# %%
import os
import pyheif
from PIL import Image

# 변환할 폴더 경로 설정
input_folder = "/Users/lol/Documents/GitHub/Photos-001"
output_folder = os.path.join(input_folder, "converted_jpg")

# 출력 폴더가 없으면 생성
os.makedirs(output_folder, exist_ok=True)

# 폴더 내 모든 HEIC/HEIF 파일 변환
for filename in os.listdir(input_folder):
    if filename.lower().endswith((".heic", ".heif")):
        input_path = os.path.join(input_folder, filename)
        output_path = os.path.join(output_folder, f"{os.path.splitext(filename)[0]}.jpg")

        try:
            # HEIC 파일 열기 및 변환
            heif_file = pyheif.read(input_path)
            image = Image.frombytes(heif_file.mode, heif_file.size, heif_file.data, "raw", heif_file.mode)

            # JPG로 저장
            image.convert("RGB").save(output_path, "JPEG", quality=95)
            print(f"✅ 변환 완료: {filename} → {output_path}")

        except Exception as e:
            print(f"⚠️ 변환 실패: {filename} | 오류: {e}")

print("✅ 모든 변환이 완료되었습니다!")
# Out:
# ⚠️ 변환 실패: IMG_4004.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_4012.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3958.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_4032.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3888.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3867.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_4033.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3934.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3918.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_4013.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3851.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3914.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3902.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_4052.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_4005.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3948.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_4018.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3933.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3876.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3860.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3905.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3856.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_4038.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3968.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3883.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3882.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3894.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3857.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3904.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3924.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3861.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3965.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3932.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3898.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3908.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3862.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_4036.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3966.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3874.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3858.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3881.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3878.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3911.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3854.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_4041.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3907.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3906.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3855.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_4017.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3947.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3880.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3859.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_4021.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3863.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3891.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_4010.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3901.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_4006.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_4030.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3960.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3937.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3961.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_4031.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3998.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3865.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3920.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_4007.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3957.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3900.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_4046.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3994.HEIC | 오류: Input is not a HEIF/AVIF file
# ⚠️ 변환 실패: IMG_3869.HEIC | 오류: Input is not a HEIF/AVIF file
# ✅ 모든 변환이 완료되었습니다!

# %%
import os
import subprocess

input_folder = "/Users/lol/Documents/GitHub/Photos-001"
output_folder = os.path.join(input_folder, "converted_jpg")

os.makedirs(output_folder, exist_ok=True)

for filename in os.listdir(input_folder):
    if filename.lower().endswith(".heic"):
        input_path = os.path.join(input_folder, filename)
        output_path = os.path.join(output_folder, f"{os.path.splitext(filename)[0]}.jpg")

        try:
            subprocess.run(["ffmpeg", "-i", input_path, output_path], check=True)
            print(f"✅ 변환 완료: {filename} → {output_path}")
        except Exception as e:
            print(f"⚠️ 변환 실패: {filename} | 오류: {e}")

print("✅ 모든 변환이 완료되었습니다!")
# Out:
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_4004.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_4004.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 4032x3024 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x7fb135111b00] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_4004.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x7fb135111b00] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x7fb135111a40] video:443KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=11.4 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.125x
# ✅ 변환 완료: IMG_4004.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_4004.jpg
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_4012.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_4012.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 4032x3024 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x7f7895f2c880] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_4012.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x7f7895f2c880] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x7f7895f2c780] video:320KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=8.2 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.173x
# ✅ 변환 완료: IMG_4012.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_4012.jpg
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_3958.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_3958.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 4032x3024 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x7fb2d480e1c0] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_3958.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x7fb2d480e1c0] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x7fb2d480e100] video:458KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=11.8 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.185x
# ✅ 변환 완료: IMG_3958.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_3958.jpg
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_4032.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_4032.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 4032x3024 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x7f7ebe010f00] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_4032.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x7f7ebe010f00] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x7f7ebe010e00] video:925KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=16.1 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.199x
# ✅ 변환 완료: IMG_4032.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_4032.jpg
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_3888.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_3888.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 4032x3024 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x7f82acf15080] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_3888.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x7f82acf15080] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x7f82acf15f80] video:460KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=12.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.217x
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# ✅ 변환 완료: IMG_3888.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_3888.jpg
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_3867.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_3867.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 4032x3024 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x7fa63aa04480] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_3867.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x7fa63aa04480] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x7fa63aa043c0] video:388KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=11.5 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.129x
# ✅ 변환 완료: IMG_3867.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_3867.jpg
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_4033.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_4033.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 4032x3024 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x7ff2a2906200] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_4033.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x