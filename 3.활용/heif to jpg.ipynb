# %%
import os
import pyheif
from PIL import Image

# 변환할 폴더 경로 설정
input_folder = "/Users/lol/Documents/GitHub/Photos-001"
output_folder = os.path.join(input_folder, "converted_jpg")

# 출력 폴더가 없으면 생성
os.makedirs(output_folder, exist_ok=True)

# 폴더 내 모든 HEIC/HEIF 파일 변환
for filename in os.listdir(input_folder):
    if filename.lower().endswith((".heic", ".heif")):
        input_path = os.path.join(input_folder, filename)
        output_path = os.path.join(output_folder, f"{os.path.splitext(filename)[0]}.jpg")

        try:
            # HEIC 파일 열기 및 변환
            heif_file = pyheif.read(input_path)
            image = Image.frombytes(heif_file.mode, heif_file.size, heif_file.data, "raw", heif_file.mode)

            # JPG로 저장
            image.convert("RGB").save(output_path, "JPEG", quality=95)
            print(f"✅ 변환 완료: {filename} → {output_path}")

        except Exception as e:
            print(f"⚠️ 변환 실패: {filename} | 오류: {e}")

print("✅ 모든 변환이 완료되었습니다!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import os
# ----> 2 import pyheif
#       3 from PIL import Image
#       5 # 변환할 폴더 경로 설정
#
# ModuleNotFoundError: No module named 'pyheif'

# %%
import os
import subprocess

input_folder = "/Users/lol/Documents/GitHub/Photos-001"
output_folder = os.path.join(input_folder, "converted_jpg")

os.makedirs(output_folder, exist_ok=True)

for filename in os.listdir(input_folder):
    if filename.lower().endswith(".heic"):
        input_path = os.path.join(input_folder, filename)
        output_path = os.path.join(output_folder, f"{os.path.splitext(filename)[0]}.jpg")

        try:
            subprocess.run(["ffmpeg", "-i", input_path, output_path], check=True)
            print(f"✅ 변환 완료: {filename} → {output_path}")
        except Exception as e:
            print(f"⚠️ 변환 실패: {filename} | 오류: {e}")

print("✅ 모든 변환이 완료되었습니다!")
# Out:
# ⚠️ 변환 실패: IMG_5422.HEIC | 오류: [Errno 2] No such file or directory: 'ffmpeg'
# ⚠️ 변환 실패: IMG_5418.HEIC | 오류: [Errno 2] No such file or directory: 'ffmpeg'
# ⚠️ 변환 실패: IMG_5419.HEIC | 오류: [Errno 2] No such file or directory: 'ffmpeg'
# ⚠️ 변환 실패: IMG_5423.HEIC | 오류: [Errno 2] No such file or directory: 'ffmpeg'
# ⚠️ 변환 실패: IMG_5428.HEIC | 오류: [Errno 2] No such file or directory: 'ffmpeg'
# ⚠️ 변환 실패: IMG_5429.HEIC | 오류: [Errno 2] No such file or directory: 'ffmpeg'
# ⚠️ 변환 실패: IMG_5425.HEIC | 오류: [Errno 2] No such file or directory: 'ffmpeg'
# ⚠️ 변환 실패: IMG_5430.HEIC | 오류: [Errno 2] No such file or directory: 'ffmpeg'
# ⚠️ 변환 실패: IMG_5426.HEIC | 오류: [Errno 2] No such file or directory: 'ffmpeg'
# ⚠️ 변환 실패: IMG_5427.HEIC | 오류: [Errno 2] No such file or directory: 'ffmpeg'
# ⚠️ 변환 실패: IMG_5431.HEIC | 오류: [Errno 2] No such file or directory: 'ffmpeg'
# ✅ 모든 변환이 완료되었습니다!

# %%
import os
import subprocess

input_folder = "/Users/lol/Documents/GitHub/Photos-001"
output_folder = os.path.join(input_folder, "converted_jpg")

os.makedirs(output_folder, exist_ok=True)

# 환경 변수에 FFmpeg 경로 추가
os.environ["PATH"] += os.pathsep + "/opt/homebrew/bin" # macOS Homebrew 기준

for filename in os.listdir(input_folder):
    if filename.lower().endswith(".heic"):
        input_path = os.path.join(input_folder, filename)
        output_path = os.path.join(output_folder, f"{os.path.splitext(filename)[0]}.jpg")

        try:
            subprocess.run(["ffmpeg", "-i", input_path, output_path], check=True)
            print(f"✅ 변환 완료: {filename} → {output_path}")
        except Exception as e:
            print(f"⚠️ 변환 실패: {filename} | 오류: {e}")

print("✅ 모든 변환이 완료되었습니다!")
# Out:
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_6701.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6701.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 4032x3024 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x15c106d70] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6701.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x15c106d70] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x15c1067b0] video:1080KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=18.7 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.341x
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_6687.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# ✅ 변환 완료: IMG_6701.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6701.jpg
# ✅ 변환 완료: IMG_6687.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6687.jpg
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6687.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 3024x4032 [SAR 1:1 DAR 3:4], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x1567073f0] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6687.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x1567073f0] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x156707330] video:484KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=12.4 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.573x
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_6795.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6795.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 3024x4032 [SAR 1:1 DAR 3:4], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x14a1072d0] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6795.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x14a1072d0] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x14a107210] video:392KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=13.6 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.828x
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_6691.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6691.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 3024x4032 [SAR 1:1 DAR 3:4], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# ✅ 변환 완료: IMG_6795.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6795.jpg
# ✅ 변환 완료: IMG_6691.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6691.jpg
# [image2 @ 0x13202f5c0] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6691.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x13202f5c0] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x13202f500] video:408KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=10.2 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.657x
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_6664.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6664.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 3024x4032 [SAR 1:1 DAR 3:4], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x146e045a0] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6664.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x146e045a0] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x146e044e0] video:301KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=9.3 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.861x
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_6799.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6799.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 4032x3024 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# ✅ 변환 완료: IMG_6664.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6664.jpg
# ✅ 변환 완료: IMG_6799.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6799.jpg
# [image2 @ 0x154e33950] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6799.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x154e33950] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x154e33890] video:422KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=9.1 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.844x
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_6776.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6776.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 3024x4032 [SAR 1:1 DAR 3:4], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x13b6314f0] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6776.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x13b6314f0] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x13b631430] video:712KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=13.9 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.478x
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_6737.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6737.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 4032x3024 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# ✅ 변환 완료: IMG_6776.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6776.jpg
# ✅ 변환 완료: IMG_6737.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6737.jpg
# ✅ 변환 완료: IMG_6809.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6809.jpg
# [image2 @ 0x13f7081a0] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6737.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x13f7081a0] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x13f7080e0] video:393KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=9.6 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.694x
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_6809.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6809.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 4032x3024 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x13ff06dd0] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6809.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x13ff06dd0] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x13ff07d60] video:431KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=13.5 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.755x
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_6761.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6761.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 3024x4032 [SAR 1:1 DAR 3:4], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x13a8081a0] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6761.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x13a8081a0] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x13a8080e0] video:593KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=13.7 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.564x
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_6798.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6798.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 4032x3024 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x146612920] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6798.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x146612920] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x146612860] video:475KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=11.8 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.714x
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_6777.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6777.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 4032x3024 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# ✅ 변환 완료: IMG_6761.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6761.jpg
# ✅ 변환 완료: IMG_6798.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6798.jpg
# [image2 @ 0x1441047d0] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6777.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x1441047d0] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x144104710] video:609KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=13.6 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.586x
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_6665.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6665.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 4032x3024 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x1337074e0] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6665.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x1337074e0] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x133707420] video:410KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=11.4 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.813x
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_6690.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6690.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 4032x3024 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x1360074e0] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6690.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x1360074e0] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x136007420] video:434KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=10.1 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.768x
# ✅ 변환 완료: IMG_6777.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6777.jpg
# ✅ 변환 완료: IMG_6665.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6665.jpg
# ✅ 변환 완료: IMG_6690.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6690.jpg
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_6805.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6805.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 4032x3024 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x138e325d0] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6805.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x138e325d0] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x138e316f0] video:568KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=13.5 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.682x
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_6669.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6669.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 4032x3024 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x1570046e0] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6669.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x1570046e0] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x157004440] video:457KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=12.1 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.753x
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# ✅ 변환 완료: IMG_6805.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6805.jpg
# ...
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6685.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 4032x3024 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x140633850] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6685.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x140633850] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x140633790] video:473KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=8.8 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.702x
# ✅ 변환 완료: IMG_6685.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6685.jpg
# ✅ 변환 완료: IMG_6735.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6735.jpg
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_6735.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6735.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 3024x4032 [SAR 1:1 DAR 3:4], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x12241f620] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6735.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x12241f620] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x12241f410] video:756KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=14.5 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.441x
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_6762.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6762.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 4032x3024 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x151030de0] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6762.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x151030de0] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x151030d20] video:289KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=9.6 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.92x
# ✅ 변환 완료: IMG_6762.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6762.jpg
# ✅ 변환 완료: IMG_6667.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6667.jpg
# ✅ 변환 완료: IMG_6684.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6684.jpg
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_6667.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6667.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 4032x3024 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x15bf07270] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6667.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x15bf07270] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x15bf06fb0] video:372KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=8.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.872x
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_6684.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6684.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 4032x3024 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x1287073f0] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6684.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x1287073f0] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x128707330] video:438KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=10.5 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.727x
# ✅ 변환 완료: IMG_6796.HEIC → /Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6796.jpg
# ✅ 모든 변환이 완료되었습니다!
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1_4 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, jpeg_pipe, from '/Users/lol/Documents/GitHub/Photos-001/IMG_6796.HEIC':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 4032x3024 [SAR 1:1 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6796.jpg':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown, progressive), 4032x3024 [SAR 1:1 DAR 4:3], q=2-31, 200 kb/s, 25 fps, 25 tbn
#       Metadata:
#         encoder         : Lavc61.19.100 mjpeg
#       Side data:
#         ICC Profile
#         cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# [image2 @ 0x12da074e0] The specified filename '/Users/lol/Documents/GitHub/Photos-001/converted_jpg/IMG_6796.jpg' does not contain an image sequence pattern or a pattern is invalid.
# [image2 @ 0x12da074e0] Use a pattern such as %03d for an image sequence or use the -update option (with -frames:v 1 if needed) to write a single image.
# [out#0/image2 @ 0x12da07420] video:503KiB audio:0KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: unknown
# frame=    1 fps=0.0 q=12.6 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.694x
