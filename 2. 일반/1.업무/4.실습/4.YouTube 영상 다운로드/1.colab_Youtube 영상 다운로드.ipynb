# %%
pip install yt_dlp xlsxwriter
# Out:
# Requirement already satisfied: yt_dlp in c:\git\python\.venv\lib\site-packages (2025.3.31)
# Requirement already satisfied: xlsxwriter in c:\git\python\.venv\lib\site-packages (3.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ![스크린샷 2025-04-17 오전 9.05.51.png](data:image/png;base64,...)

# %%
import yt_dlp
import xlsxwriter
import os

url = "https://youtu.be/cAL-Z_FfObI?si=ZxsGC75_kqkHLRPn"

# Define options to list available formats
list_opts = {
    'listformats': False,  # Do not use the built-in listformats to allow more detailed output
}

try:
    # List available formats
    with yt_dlp.YoutubeDL(list_opts) as ydl:
        info = ydl.extract_info(url, download=False)
        formats = info.get('formats', [])
        print("Available formats:")

        # Create a workbook and add a worksheet
        workbook = xlsxwriter.Workbook('available_formats.xlsx')
        worksheet = workbook.add_worksheet()

        # Write headers
        worksheet.write('A1', 'Format ID')
        worksheet.write('B1', 'Resolution')
        worksheet.write('C1', 'Filesize')
        worksheet.write('D1', 'Note')
        worksheet.write('E1', 'Type')
        worksheet.write('F1', 'Extension')

        # Write format details to worksheet
        row = 1
        for f in formats:
            format_id = f['format_id']
            resolution = f.get('height', 'audio only') if 'height' in f else 'unknown'
            filesize = f.get('filesize', 'unknown')
            format_note = f.get('format_note', 'unknown')
            ext = f.get('ext', 'unknown')
            media_type = 'audio' if f.get('vcodec', 'none') == 'none' else 'video'

            # Print to console
            print(f"Format ID: {format_id}, Resolution: {resolution}, Filesize: {filesize}, Note: {format_note}, Type: {media_type}, Extension: {ext}")

            # Write to Excel file
            worksheet.write(row, 0, format_id)
            worksheet.write(row, 1, resolution)
            worksheet.write(row, 2, filesize)
            worksheet.write(row, 3, format_note)
            worksheet.write(row, 4, media_type)
            worksheet.write(row, 5, ext)
            row += 1

        # Close the workbook
        workbook.close()
        print("Format list saved to available_formats.xlsx")

    # Prompt the user to select a video format
    selected_video_format = input("Enter the video format ID you want to download: ")

    # Find the selected video format in the formats list
    video_format = next((f for f in formats if f['format_id'] == selected_video_format), None)
    if not video_format:
        raise ValueError("Invalid video format ID selected.")

    # Define options to download the selected video format with throttled download speed
    video_output = 'video_only.' + video_format['ext']
    ydl_opts_video = {
        'format': selected_video_format,  # Use the selected format ID for video
        'outtmpl': video_output,  # Output file name format for video
        'ratelimit': 500000,  # Limit download speed to 500 KB/s
    }

    # Download the video in the selected format
    with yt_dlp.YoutubeDL(ydl_opts_video) as ydl:
        ydl.download([url])
    print("Video downloaded successfully!")

    # Prompt the user to select an audio format
    selected_audio_format = input("Enter the audio format ID you want to download: ")

    # Find the selected audio format in the formats list
    audio_format = next((f for f in formats if f['format_id'] == selected_audio_format), None)
    if not audio_format:
        raise ValueError("Invalid audio format ID selected.")

    # Define options to download the selected audio format
    audio_output = 'audio_only.' + audio_format['ext']
    ydl_opts_audio = {
        'format': selected_audio_format,  # Use the selected format ID for audio
        'outtmpl': audio_output,  # Output file name format for audio
        'ratelimit': 500000,  # Limit download speed to 500 KB/s
    }

    # Download the audio in the selected format
    with yt_dlp.YoutubeDL(ydl_opts_audio) as ydl:
        ydl.download([url])
    print("Audio downloaded successfully!")

    # Merge video and audio using ffmpeg
    merged_output = 'final_output.mp4'
    os.system(f"ffmpeg -i {video_output} -i {audio_output} -c:v copy -c:a aac -strict experimental {merged_output}")
    print(f"Video and audio merged successfully into {merged_output}!")

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# [youtube] Extracting URL: https://youtu.be/cAL-Z_FfObI?si=ZxsGC75_kqkHLRPn
# [youtube] cAL-Z_FfObI: Downloading webpage
# [youtube] cAL-Z_FfObI: Downloading tv client config
# [youtube] cAL-Z_FfObI: Downloading player 9a279502-main
# [youtube] cAL-Z_FfObI: Downloading tv player API JSON
# [youtube] cAL-Z_FfObI: Downloading ios player API JSON
# [youtube] cAL-Z_FfObI: Downloading m3u8 information
# WARNING: ffmpeg not found. The downloaded format may not be the best available. Installing ffmpeg is strongly recommended: https://github.com/yt-dlp/yt-dlp#dependencies
# Available formats:
# Format ID: sb3, Resolution: 27, Filesize: unknown, Note: storyboard, Type: audio, Extension: mhtml
# Format ID: sb2, Resolution: 45, Filesize: unknown, Note: storyboard, Type: audio, Extension: mhtml
# Format ID: sb1, Resolution: 90, Filesize: unknown, Note: storyboard, Type: audio, Extension: mhtml
# Format ID: sb0, Resolution: 180, Filesize: unknown, Note: storyboard, Type: audio, Extension: mhtml
# Format ID: 233, Resolution: unknown, Filesize: unknown, Note: Default, low, Type: audio, Extension: mp4
# Format ID: 234, Resolution: unknown, Filesize: unknown, Note: Default, high, Type: audio, Extension: mp4
# Format ID: 249, Resolution: None, Filesize: 1626053, Note: low, Type: audio, Extension: webm
# Format ID: 250, Resolution: None, Filesize: 2069471, Note: low, Type: audio, Extension: webm
# Format ID: 140, Resolution: None, Filesize: 4015327, Note: medium, Type: audio, Extension: m4a
# Format ID: 251, Resolution: None, Filesize: 3593412, Note: medium, Type: audio, Extension: webm
# Format ID: 602, Resolution: 128, Filesize: unknown, Note: unknown, Type: video, Extension: mp4
# Format ID: 269, Resolution: 128, Filesize: unknown, Note: unknown, Type: video, Extension: mp4
# Format ID: 160, Resolution: 128, Filesize: 933934, Note: 144p, Type: video, Extension: mp4
# Format ID: 603, Resolution: 128, Filesize: unknown, Note: unknown, Type: video, Extension: mp4
# Format ID: 278, Resolution: 128, Filesize: 1962879, Note: 144p, Type: video, Extension: webm
# Format ID: 394, Resolution: 128, Filesize: 1397450, Note: 144p, Type: video, Extension: mp4
# Format ID: 229, Resolution: 182, Filesize: unknown, Note: unknown, Type: video, Extension: mp4
# Format ID: 133, Resolution: 182, Filesize: 1964403, Note: 240p, Type: video, Extension: mp4
# Format ID: 604, Resolution: 182, Filesize: unknown, Note: unknown, Type: video, Extension: mp4
# Format ID: 242, Resolution: 182, Filesize: 2775941, Note: 240p, Type: video, Extension: webm
# Format ID: 395, Resolution: 182, Filesize: 1782712, Note: 240p, Type: video, Extension: mp4
# Format ID: 230, Resolution: 272, Filesize: unknown, Note: unknown, Type: video, Extension: mp4
# Format ID: 134, Resolution: 272, Filesize: 3539120, Note: 360p, Type: video, Extension: mp4
# Format ID: 18, Resolution: 272, Filesize: None, Note: 360p, Type: video, Extension: mp4
# Format ID: 605, Resolution: 272, Filesize: unknown, Note: unknown, Type: video, Extension: mp4
# Format ID: 243, Resolution: 272, Filesize: 6290143, Note: 360p, Type: video, Extension: webm
# Format ID: 396, Resolution: 272, Filesize: 3223924, Note: 360p, Type: video, Extension: mp4
# Format ID: 231, Resolution: 364, Filesize: unknown, Note: unknown, Type: video, Extension: mp4
# Format ID: 135, Resolution: 364, Filesize: 6749936, Note: 480p, Type: video, Extension: mp4
# Format ID: 606, Resolution: 364, Filesize: unknown, Note: unknown, Type: video, Extension: mp4
# Format ID: 244, Resolution: 364, Filesize: 9726100, Note: 480p, Type: video, Extension: webm
# Format ID: 397, Resolution: 364, Filesize: 5794204, Note: 480p, Type: video, Extension: mp4
# Format ID: 232, Resolution: 544, Filesize: unknown, Note: unknown, Type: video, Extension: mp4
# Format ID: 136, Resolution: 544, Filesize: 12270327, Note: 720p, Type: video, Extension: mp4
# Format ID: 609, Resolution: 544, Filesize: unknown, Note: unknown, Type: video, Extension: mp4
# Format ID: 247, Resolution: 544, Filesize: 17814990, Note: 720p, Type: video, Extension: webm
# Format ID: 398, Resolution: 544, Filesize: 10888542, Note: 720p, Type: video, Extension: mp4
# Format ID: 270, Resolution: 818, Filesize: unknown, Note: unknown, Type: video, Extension: mp4
# Format ID: 137, Resolution: 818, Filesize: 34448452, Note: 1080p, Type: video, Extension: mp4
# Format ID: 614, Resolution: 818, Filesize: unknown, Note: unknown, Type: video, Extension: mp4
# Format ID: 248, Resolution: 818, Filesize: 27945682, Note: 1080p, Type: video, Extension: webm
# Format ID: 399, Resolution: 818, Filesize: 19719547, Note: 1080p, Type: video, Extension: mp4
# Format ID: 620, Resolution: 1090, Filesize: unknown, Note: unknown, Type: video, Extension: mp4
# Format ID: 271, Resolution: 1090, Filesize: 72216430, Note: 1440p, Type: video, Extension: webm
# Format ID: 400, Resolution: 1090, Filesize: 58002138, Note: 1440p, Type: video, Extension: mp4
# Format ID: 625, Resolution: 1634, Filesize: unknown, Note: unknown, Type: video, Extension: mp4
# Format ID: 313, Resolution: 1634, Filesize: 192381573, Note: 2160p, Type: video, Extension: webm
# Format ID: 401, Resolution: 1634, Filesize: 106431916, Note: 2160p, Type: video, Extension: mp4
# Format list saved to available_formats.xlsx
# [youtube] Extracting URL: https://youtu.be/cAL-Z_FfObI?si=ZxsGC75_kqkHLRPn
# [youtube] cAL-Z_FfObI: Downloading webpage
# [youtube] cAL-Z_FfObI: Downloading tv client config
# [youtube] cAL-Z_FfObI: Downloading player 9a279502-main
# [youtube] cAL-Z_FfObI: Downloading tv player API JSON
# [youtube] cAL-Z_FfObI: Downloading ios player API JSON
# [youtube] cAL-Z_FfObI: Downloading m3u8 information
# [info] cAL-Z_FfObI: Downloading 1 format(s): 160
# [download] Destination: video_only.mp4
# [download] 100% of  912.04KiB in 00:00:02 at 376.04KiB/s
# Video downloaded successfully!
# [youtube] Extracting URL: https://youtu.be/cAL-Z_FfObI?si=ZxsGC75_kqkHLRPn
# [youtube] cAL-Z_FfObI: Downloading webpage
# [youtube] cAL-Z_FfObI: Downloading tv client config
# [youtube] cAL-Z_FfObI: Downloading player 9a279502-main
# [youtube] cAL-Z_FfObI: Downloading tv player API JSON
# [youtube] cAL-Z_FfObI: Downloading ios player API JSON
# [youtube] cAL-Z_FfObI: Downloading m3u8 information
# [info] cAL-Z_FfObI: Downloading 1 format(s): 233
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 45
# [download] Destination: audio_only.mp4
# [download] 100% of    1.46MiB in 00:00:04 at 326.01KiB/s
# WARNING: cAL-Z_FfObI: Possible MPEG-TS in MP4 container or malformed AAC timestamps. Install ffmpeg to fix this automatically
# Audio downloaded successfully!
# Video and audio merged successfully into final_output.mp4!
